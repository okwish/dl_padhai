# %%
import pandas as pd

# %%
df = pd.read_csv('mobile_cleaned.csv') #get dataframe
#read_xls to read excel file

# %%
df.head()
# Out:
#    sim_type  aperture  gpu_rank  weight  stand_by_time  processor_frequency  \
# 0         0        12        55   155.0            250                  1.3
# 1         0         1        55   132.0            300                  1.3
# 2         0         9        55   142.0            329                  1.5
# 3         0         8        55   152.0            385                  1.3
# 4         1         1        55   234.0            385                  1.3
#
#    thickness  flash_type  front_camera_resolution  auto_focus  ...  \
# 0       10.5           5                     2.00           0  ...
# 1       10.6           5                     0.30           1  ...
# 2        8.5           5                     2.00           3  ...
# 3        8.0           5                     2.00           3  ...
# 4        7.9           5                     1.92           3  ...
#
#    micro_sd_slot  screen_pixel_density  water_proof_rate  phone_width  \
# ...

# %%
dir(df) #shows all functions available on that class.
# Out:
# ['FM',
#  'T',
#  '_AXIS_LEN',
#  '_AXIS_ORDERS',
#  '_AXIS_TO_AXIS_NUMBER',
#  '_HANDLED_TYPES',
#  '__abs__',
#  '__add__',
#  '__and__',
#  '__annotations__',
#  '__array__',
#  '__array_priority__',
#  '__array_ufunc__',
#  '__array_wrap__',
#  '__bool__',
#  '__class__',
#  '__contains__',
#  '__copy__',
#  '__deepcopy__',
#  '__delattr__',
#  '__delitem__',
#  '__dict__',
#  '__dir__',
#  '__divmod__',
#  '__doc__',
#  '__eq__',
#  '__finalize__',
#  '__floordiv__',
#  '__format__',
#  '__ge__',
#  '__getattr__',
#  '__getattribute__',
#  '__getitem__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__iadd__',
#  '__iand__',
#  '__ifloordiv__',
#  '__imod__',
#  '__imul__',
#  '__init__',
#  '__init_subclass__',
#  '__invert__',
#  '__ior__',
#  '__ipow__',
#  '__isub__',
#  '__iter__',
#  '__itruediv__',
#  '__ixor__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__matmul__',
#  '__mod__',
#  '__module__',
#  '__mul__',
#  '__ne__',
#  '__neg__',
#  '__new__',
# ...

# %% [markdown]
# In python everything is an object. Every object has an identity(integer id number), type(like the blueprint class), and contents. id(obj) returns the id; type(df) returns the type.

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
len(df) #number of rows (data points)
# Out:
# 109

# %%
df.shape # rows x cols
# Out:
# (109, 40)

# %%
df.loc[5] #that specific row (datapoint) [one datapoint => row]
# Out:
# sim_type                                0.0
# aperture                               14.0
# gpu_rank                               55.0
# weight                                179.0
# stand_by_time                         280.0
# processor_frequency                     1.3
# thickness                               7.9
# flash_type                              5.0
# front_camera_resolution                 5.0
# auto_focus                              3.0
# screen_size                             5.5
# frames_per_second                      30.0
# FM                                      3.0
# no_of_reviews_in_gsmarena_in_week       6.0
# os                                      0.0
# phone_height                          150.0
# screen_protection                       5.0
# sim_size                                3.0
# price                                5999.0
# talk_time                              22.0
# video_resolution                      720.0
# ...

# %%
df_short = df[0:10] #slicing #on ROWS(datapoints)

# %%
# selecting columns with list-of-column-names

df_thin = df[['stand_by_time', 'expandable_memory', 'price', 'battery_capacity','is_liked']] 
#'list' of col names within []
df_thin.head()
#dealing with only needed cols.
# Out:
#    stand_by_time  expandable_memory  price  battery_capacity  is_liked
# 0            250               64.0   3870              2000         1
# 1            300               32.0   4059              2000         1
# 2            329               32.0   4777              2500         0
# 3            385               32.0   5799              3000         1
# 4            385               32.0   5990              3000         0

# %%
# selecting with list-of-bools

df_liked = df_thin[ df_thin['is_liked']==1 ]

# %%
type(df_thin['is_liked']==1)

#df_thin['is_liked']==1 :
#returns a series(list-ish) - with bool values.

#'list' in [] like before.

#list with bools corresponding to each col is another way to select.
# Out:
# pandas.core.series.Series

# %%
df_thin['price'].mean()
# Out:
# 19373.211009174312

# %%
df_thin['price'].describe()
# Out:
# count      109.000000
# mean     19373.211009
# std      14039.197220
# min       3870.000000
# 25%       8999.000000
# 50%      14614.000000
# 75%      24999.000000
# max      64500.000000
# Name: price, dtype: float64

# %%
df_thin.describe() #do for each col
# Out:
#        stand_by_time  expandable_memory         price  battery_capacity  \
# count      109.00000         109.000000    109.000000        109.000000
# mean       404.66055         104.513761  19373.211009       2841.779817
# std        176.44206         275.799767  14039.197220        655.003963
# min        160.00000           0.000000   3870.000000       1560.000000
# 25%        264.00000           0.000000   8999.000000       2470.000000
# 50%        360.00000          32.000000  14614.000000       2900.000000
# 75%        500.00000         128.000000  24999.000000       3100.000000
# max       1093.00000        2048.000000  64500.000000       5000.000000
#
#          is_liked
# count  109.000000
# mean     0.844037
# std      0.364496
# min      0.000000
# 25%      1.000000
# 50%      1.000000
# 75%      1.000000
# max      1.000000

# %%
df_thin[df_thin['is_liked']==1]['price'].mean() 
#selecting, then on col of that, then calling fn on that
#think what returned, where.. 

# adding more stuff to what was returned
# Out:
# 19393.239130434784

# %%
#statistics across different features(cols)
g = df_thin.groupby(['is_liked'])
#divide the dataframe into multiple dataframes- one for each key
#key => the col 'value'.
#return data_frame_group_by - like dictionary..

# %%
for key, df in g:
    print(key)
    print(df)
# Out:
# 0
#      stand_by_time  expandable_memory  price  battery_capacity  is_liked
# 2              329               32.0   4777              2500         0
# 4              385               32.0   5990              3000         0
# 5              280               32.0   5999              2900         0
# 11             300              128.0   6990              2600         0
# 22             354              128.0   7999              2400         0
# 38             490               32.0   9999              2100         0
# 53             345               64.0  14300              2950         0
# 60             840                0.0  15689              4100         0
# 74             390              128.0  21999              2800         0
# 77             620              128.0  22999              3100         0
# 78             618                0.0  24499              3600         0
# 80             598                0.0  24999              3000         0
# ...

# %%
g.mean()

df_thin.groupby(['is_liked']).mean()

#this way we can see statistics of different classes(values)
#in a col.
# Out:
#           stand_by_time  expandable_memory         price  battery_capacity
# is_liked
# 0            457.235294          68.235294  19264.823529       2874.941176
# 1            394.945652         111.217391  19393.239130       2835.652174

# %%
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()

# %%
ax = sns.pairplot(df_thin, diag_kind='hist') #diagonal_kind
#plot and return something.

# %%
ax = sns.pairplot(df_thin, diag_kind='hist',hue='is_liked')
#hue based on is_liked value
